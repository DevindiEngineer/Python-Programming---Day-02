# %%
5+2
# Out:
# 7

# %%
5-3
# Out:
# 2

# %%
5*2
# Out:
# 10

# %%
5/2
# Out:
# 2.5

# %%
5**2
# Out:
# 25

# %%
3**3
# Out:
# 27

# %%
11%2
# Out:
# 1

# %%
(5+3)*2**2-10/5+7%3
# Out:
# 31.0

# %%
a=5
b=2
c=a/b
d=a//b
print(c)
print(d)
# Out:
# 2.5
# 2

# %%
x=50
y=10
x=y
print(x)
# Out:
# 10

# %%
x=50
y=10
x+=y
print(x)
# Out:
# 60

# %%
x=50
y=10
x-=y
print(x)
# Out:
# 40

# %%
x=50
y=10
x*=y
print(x)
# Out:
# 500

# %%
x=50
y=10
x/=y
print(x) # floate value
# Out:
# 5.0

# %%
x=50
y=10
x//=y
print(x) #int value
# Out:
# 5

# %%
x=50
y=10
x%=y
print(x)
# Out:
# 0

# %%
x=50
y=10
x**=y
print(x)
# Out:
# 97656250000000000

# %%
a,b,c=1,2,3
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
a=b=c=1
print(a)
print(b)
print(c)
# Out:
# 1
# 1
# 1
